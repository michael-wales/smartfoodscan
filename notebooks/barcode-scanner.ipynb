# %% [markdown]
# # BARCODE SCANNER

# %% [markdown]
# ## Module to read the barcode from a picture

# %%
from pyzbar.pyzbar import decode
from PIL import Image
import cv2
import numpy as np


# Load the image
# Load the image
image = Image.open('../images/barcode.jpeg')

def barcode_scanner(image):
    image = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    # Decode the barcode
    decoded = decode(image)

    # Print the barcode data and type
    for barcode in decoded:
        
        return int(barcode.data.decode("utf-8"))

#barcode number as int
key = barcode_scanner(image)
key
# Out:
# 4890008100309

# %% [markdown]
# ### CALL TO API

# %%
#call API 
import pandas as pd
import requests
import json

#make the request to the API
def get_food_data(key):
    url = f"https://world.openfoodfacts.org/api/v0/product/{key}.json"
    response = requests.get(url)
    if response.status_code == 200: 
        data = response.json()
        if data.get('status')== 1:
            return data['product']
        else:
            return f"Product not found"
    else:
        return f"Error connection with the API: {response.status_code}"
    

food_data =get_food_data(key)
food_data
# Out:
# {'_id': '4890008100309',
#  '_keywords': ['beverage',
#   'carbonated',
#   'coca',
#   'coca-cola',
#   'cola',
#   'drink',
#   'soda',
#   'sweetened'],
#  'added_countries_tags': [],
#  'additives_n': 2,
#  'additives_original_tags': ['en:e150d', 'en:e338'],
#  'additives_tags': ['en:e150d', 'en:e338'],
#  'allergens': '',
#  'allergens_from_ingredients': '',
#  'allergens_from_user': '(en) ',
#  'allergens_hierarchy': [],
#  'allergens_tags': [],
#  'amino_acids_prev_tags': [],
#  'amino_acids_tags': [],
#  'brands': 'Coca Cola',
#  'brands_tags': ['coca-cola'],
#  'categories': 'Beverages, Carbonated drinks, Sodas, Colas, Sweetened beverages',
#  'categories_hierarchy': ['en:beverages',
#   'en:carbonated-drinks',
#   'en:sodas',
#   'en:colas',
#   'en:sweetened-beverages'],
#  'categories_lc': 'en',
#  'categories_old': 'Beverages, Carbonated drinks, Sodas, Colas, Sweetened beverages',
#  'categories_properties': {'agribalyse_proxy_food_code:en': '18018',
#   'ciqual_food_code:en': '18063'},
#  'categories_properties_tags': ['all-products',
#   'categories-known',
#   'agribalyse-food-code-unknown',
#   'agribalyse-proxy-food-code-18018',
#   'agribalyse-proxy-food-code-known',
#   'ciqual-food-code-18063',
#   'ciqual-food-code-known',
#   'agribalyse-known',
#   'agribalyse-18018'],
#  'categories_tags': ['en:beverages',
#   'en:carbonated-drinks',
#   'en:sodas',
#   'en:colas',
#   'en:sweetened-beverages'],
#  'category_properties': {'ciqual_food_name:en': 'Cola, sugar and sweetener-s- content -average-',
#   'ciqual_food_name:fr': 'Cola, teneur en sucre et édulcorant inconnue -aliment moyen-'},
#  'checkers_tags': [],
#  'ciqual_food_name_tags': ['cola-sugar-and-sweetener-s-content-average'],
#  'cities_tags': [],
#  'code': '4890008100309',
#  'codes_tags': ['code-13',
#   '4890008100xxx',
#   '489000810xxxx',
#   '48900081xxxxx',
#   '4890008xxxxxx',
#   '489000xxxxxxx',
#   '48900xxxxxxxx',
#   '4890xxxxxxxxx',
#   '489xxxxxxxxxx',
#   '48xxxxxxxxxxx',
#   '4xxxxxxxxxxxx'],
#  'compared_to_category': 'en:sweetened-beverages',
#  'complete': 0,
#  'completeness': 0.775,
#  'correctors_tags': ['momowong',
#   'tacite',
#   'openfoodfacts-contributors',
#   'kinosan',
#   'packbot'],
#  'countries': 'Hong Kong',
#  'countries_debug_tags': [],
#  'countries_hierarchy': ['en:hong-kong'],
#  'countries_lc': 'en',
#  'countries_tags': ['en:hong-kong'],
#  'created_t': 1451464186,
#  'creator': 'momowong',
#  'data_quality_bugs_tags': [],
#  'data_quality_errors_tags': [],
#  'data_quality_info_tags': ['en:packaging-data-incomplete',
#   'en:ingredients-percent-analysis-ok',
#   'en:environmental-score-extended-data-not-computed',
#   'en:food-groups-1-known',
#   'en:food-groups-2-known',
#   'en:food-groups-3-unknown'],
#  'data_quality_tags': ['en:packaging-data-incomplete',
#   'en:ingredients-percent-analysis-ok',
#   'en:environmental-score-extended-data-not-computed',
#   'en:food-groups-1-known',
#   'en:food-groups-2-known',
#   'en:food-groups-3-unknown',
#   'en:ingredients-50-percent-unknown',
#   'en:environmental-score-origins-of-ingredients-origins-are-100-percent-unknown',
#   'en:environmental-score-production-system-no-label'],
#  'data_quality_warnings_tags': ['en:ingredients-50-percent-unknown',
#   'en:environmental-score-origins-of-ingredients-origins-are-100-percent-unknown',
#   'en:environmental-score-production-system-no-label'],
#  'data_sources': 'App - Open Food Facts, Apps, App - smoothie-openfoodfacts',
#  'data_sources_tags': ['app-open-food-facts',
#   'apps',
#   'app-smoothie-openfoodfacts'],
#  'ecoscore_data': {'adjustments': {'origins_of_ingredients': {'aggregated_origins': [{'epi_score': 0,
#       'origin': 'en:unknown',
#       'percent': 100,
#       'transportation_score': 0}],
#     'epi_score': 0,
#     'epi_value': -5,
#     'origins_from_categories': ['en:unknown'],
#     'origins_from_origins_field': ['en:unknown'],
#     'transportation_score': 0,
#     'transportation_scores': {'ad': 0,
#      'al': 0,
#      'at': 0,
#      'ax': 0,
#      'ba': 0,
#      'be': 0,
#      'bg': 0,
#      'ch': 0,
#      'cy': 0,
#      'cz': 0,
#      'de': 0,
#      'dk': 0,
#      'dz': 0,
#      'ee': 0,
#      'eg': 0,
#      'es': 0,
#      'fi': 0,
#      'fo': 0,
#      'fr': 0,
#      'gg': 0,
#      'gi': 0,
#      'gr': 0,
#      'hr': 0,
#      'hu': 0,
#      'ie': 0,
#      'il': 0,
#      'im': 0,
#      'is': 0,
#      'it': 0,
#      'je': 0,
#      'lb': 0,
#      'li': 0,
#      'lt': 0,
#      'lu': 0,
#      'lv': 0,
#      'ly': 0,
#      'ma': 0,
#      'mc': 0,
#      'md': 0,
#      'me': 0,
#      'mk': 0,
#      'mt': 0,
#      'nl': 0,
#      'no': 0,
#      'pl': 0,
#      'ps': 0,
#      'pt': 0,
#      'ro': 0,
#      'rs': 0,
#      'se': 0,
#      'si': 0,
#      'sj': 0,
#      'sk': 0,
#      'sm': 0,
#      'sy': 0,
#      'tn': 0,
#      'tr': 0,
#      'ua': 0,
#      'uk': 0,
#      'us': 0,
#      'va': 0,
#      'world': 0,
#      'xk': 0},
#     'transportation_value': 0,
#     'transportation_values': {'ad': 0,
#      'al': 0,
#      'at': 0,
#      'ax': 0,
#      'ba': 0,
#      'be': 0,
#      'bg': 0,
#      'ch': 0,
#      'cy': 0,
#      'cz': 0,
#      'de': 0,
#      'dk': 0,
#      'dz': 0,
#      'ee': 0,
#      'eg': 0,
#      'es': 0,
#      'fi': 0,
#      'fo': 0,
#      'fr': 0,
#      'gg': 0,
#      'gi': 0,
#      'gr': 0,
#      'hr': 0,
#      'hu': 0,
#      'ie': 0,
#      'il': 0,
#      'im': 0,
#      'is': 0,
#      'it': 0,
#      'je': 0,
#      'lb': 0,
#      'li': 0,
#      'lt': 0,
#      'lu': 0,
#      'lv': 0,
#      'ly': 0,
#      'ma': 0,
#      'mc': 0,
#      'md': 0,
#      'me': 0,
#      'mk': 0,
#      'mt': 0,
#      'nl': 0,
#      'no': 0,
#      'pl': 0,
#      'ps': 0,
#      'pt': 0,
#      'ro': 0,
#      'rs': 0,
#      'se': 0,
#      'si': 0,
#      'sj': 0,
#      'sk': 0,
#      'sm': 0,
#      'sy': 0,
#      'tn': 0,
#      'tr': 0,
#      'ua': 0,
#      'uk': 0,
#      'us': 0,
#      'va': 0,
#      'world': 0,
#      'xk': 0},
#     'value': -5,
#     'values': {'ad': -5,
#      'al': -5,
#      'at': -5,
#      'ax': -5,
#      'ba': -5,
#      'be': -5,
#      'bg': -5,
#      'ch': -5,
#      'cy': -5,
#      'cz': -5,
#      'de': -5,
#      'dk': -5,
#      'dz': -5,
#      'ee': -5,
#      'eg': -5,
#      'es': -5,
#      'fi': -5,
#      'fo': -5,
#      'fr': -5,
#      'gg': -5,
#      'gi': -5,
#      'gr': -5,
#      'hr': -5,
#      'hu': -5,
#      'ie': -5,
#      'il': -5,
#      'im': -5,
#      'is': -5,
#      'it': -5,
#      'je': -5,
#      'lb': -5,
#      'li': -5,
#      'lt': -5,
#      'lu': -5,
#      'lv': -5,
#      'ly': -5,
#      'ma': -5,
#      'mc': -5,
#      'md': -5,
#      'me': -5,
#      'mk': -5,
#      'mt': -5,
#      'nl': -5,
#      'no': -5,
#      'pl': -5,
#      'ps': -5,
#      'pt': -5,
#      'ro': -5,
#      'rs': -5,
#      'se': -5,
#      'si': -5,
#      'sj': -5,
#      'sk': -5,
#      'sm': -5,
#      'sy': -5,
#      'tn': -5,
#      'tr': -5,
#      'ua': -5,
#      'uk': -5,
#      'us': -5,
#      'va': -5,
#      'world': -5,
#      'xk': -5},
#     'warning': 'origins_are_100_percent_unknown'},
#    'packaging': {'non_recyclable_and_non_biodegradable_materials': 0,
#     'packagings': [{'environmental_score_material_score': 72,
#       'environmental_score_shape_ratio': 1,
#       'material': 'en:heavy-aluminium',
#       'shape': 'en:can'}],
#     'score': 72,
#     'value': -3},
#    'production_system': {'labels': [], 'value': 0, 'warning': 'no_label'},
#    'threatened_species': {}},
#   'environmental_score_not_applicable_for_category': 'en:sodas',
#   'missing': {'labels': 1, 'origins': 1},
#   'scores': {},
#   'status': 'unknown'},
#  'ecoscore_grade': 'not-applicable',
#  'ecoscore_tags': ['not-applicable'],
#  'editors_tags': ['smoothie-app',
#   'packbot',
#   'momowong',
#   'tacite',
#   'kinosan',
#   'openfoodfacts-contributors'],
#  'emb_codes': '',
#  'emb_codes_20141016': '',
#  'emb_codes_orig': '',
#  'emb_codes_tags': [],
#  'entry_dates_tags': ['2015-12-30', '2015-12', '2015'],
#  'expiration_date': '',
#  'food_groups': 'en:sweetened-beverages',
#  'food_groups_tags': ['en:beverages', 'en:sweetened-beverages'],
#  'fruits-vegetables-nuts_100g_estimate': 0,
#  'generic_name': '',
#  'generic_name_en': '',
#  'id': '2000000025722',
#  'image_front_small_url': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/front_en.4.200.jpg',
#  'image_front_thumb_url': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/front_en.4.100.jpg',
#  'image_front_url': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/front_en.4.400.jpg',
#  'image_ingredients_small_url': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/ingredients_en.9.200.jpg',
#  'image_ingredients_thumb_url': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/ingredients_en.9.100.jpg',
#  'image_ingredients_url': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/ingredients_en.9.400.jpg',
#  'image_small_url': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/front_en.4.200.jpg',
#  'image_thumb_url': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/front_en.4.100.jpg',
#  'image_url': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/front_en.4.400.jpg',
#  'images': {'1': {'sizes': {'100': {'h': 100, 'w': 56},
#     '400': {'h': 400, 'w': 225},
#     'full': {'h': 5376, 'w': 3024}},
#    'uploaded_t': '1451464260',
#    'uploader': 'momowong'},
#   '2': {'sizes': {'100': {'h': 12, 'w': 100},
#     '400': {'h': 50, 'w': 400},
#     'full': {'h': 376, 'w': 3024}},
#    'uploaded_t': 1638425974,
#    'uploader': 'kinosan'},
#   'front': {'geometry': '0x0-0-0',
#    'imgid': '1',
#    'normalize': 'true',
#    'rev': '4',
#    'sizes': {'100': {'h': 100, 'w': 56},
#     '200': {'h': 200, 'w': 113},
#     '400': {'h': 400, 'w': 225},
#     'full': {'h': 5376, 'w': 3024}},
#    'white_magic': 'false'},
#   'front_en': {'geometry': '0x0-0-0',
#    'imgid': '1',
#    'normalize': 'true',
#    'rev': '4',
#    'sizes': {'100': {'h': 100, 'w': 56},
#     '200': {'h': 200, 'w': 113},
#     '400': {'h': 400, 'w': 225},
#     'full': {'h': 5376, 'w': 3024}},
#    'white_magic': 'false'},
#   'ingredients_en': {'angle': None,
#    'coordinates_image_size': '400',
#    'geometry': '0x0-0-0',
#    'imgid': '2',
#    'normalize': None,
#    'rev': '9',
#    'sizes': {'100': {'h': 12, 'w': 100},
#     '200': {'h': 25, 'w': 200},
#     '400': {'h': 50, 'w': 400},
#     'full': {'h': 376, 'w': 3024}},
#    'white_magic': None,
#    'x1': None,
#    'x2': None,
#    'y1': None,
#    'y2': None}},
#  'informers_tags': ['momowong', 'tacite', 'kinosan'],
#  'ingredients': [{'ciqual_food_code': '18066',
#    'ecobalyse_code': 'tap-water',
#    'id': 'en:carbonated-water',
#    'is_in_taxonomy': 1,
#    'percent_estimate': 73.5,
#    'percent_max': 100,
#    'percent_min': 47,
#    'rank': 1,
#    'text': 'Carbonated Water',
#    'vegan': 'yes',
#    'vegetarian': 'yes'},
#   {'ciqual_proxy_food_code': '31016',
#    'ecobalyse_code': 'sugar',
#    'id': 'en:sugar',
#    'is_in_taxonomy': 1,
#    'percent_estimate': 5.3,
#    'percent_max': 10.6,
#    'percent_min': 0,
#    'rank': 2,
#    'text': 'Sugar',
#    'vegan': 'yes',
#    'vegetarian': 'yes'},
#   {'has_sub_ingredients': 'yes',
#    'id': 'en:colour',
#    'is_in_taxonomy': 1,
#    'percent_estimate': 5.3,
#    'percent_max': 10.6,
#    'percent_min': 0,
#    'rank': 3,
#    'text': 'Colour'},
#   {'has_sub_ingredients': 'yes',
#    'id': 'en:acidity-requlator',
#    'is_in_taxonomy': 0,
#    'percent_estimate': 5.3,
#    'percent_max': 10.6,
#    'percent_min': 0,
#    'rank': 4,
#    'text': 'Acidity Requlator'},
#   {'id': 'en:caffeine',
#    'is_in_taxonomy': 1,
#    'percent_estimate': 5.3,
#    'percent_max': 10.6,
#    'percent_min': 0,
#    'rank': 5,
#    'text': 'Caffeine',
#    'vegan': 'yes',
#    'vegetarian': 'yes'},
#   {'id': 'en:other-flavourings',
#    'is_in_taxonomy': 0,
#    'percent_estimate': 5.30000000000001,
#    'percent_max': 10.6,
#    'percent_min': 0,
#    'rank': 6,
#    'text': 'other Flavourings'},
#   {'id': 'en:150d',
#    'is_in_taxonomy': 0,
#    'percent_estimate': 5.3,
#    'percent_max': 10.6,
#    'percent_min': 0,
#    'text': '150d'},
#   {'id': 'en:338',
#    'is_in_taxonomy': 0,
#    'percent_estimate': 5.3,
#    'percent_max': 10.6,
#    'percent_min': 0,
#    'text': '338'}],
#  'ingredients_analysis': {'en:palm-oil-content-unknown': ['en:150d',
#    'en:acidity-requlator',
#    'en:338',
#    'en:other-flavourings'],
#   'en:vegan-status-unknown': ['en:150d',
#    'en:acidity-requlator',
#    'en:338',
#    'en:other-flavourings'],
#   'en:vegetarian-status-unknown': ['en:150d',
#    'en:acidity-requlator',
#    'en:338',
#    'en:other-flavourings']},
#  'ingredients_analysis_tags': ['en:palm-oil-content-unknown',
#   'en:vegan-status-unknown',
#   'en:vegetarian-status-unknown'],
#  'ingredients_debug': [],
#  'ingredients_from_or_that_may_be_from_palm_oil_n': 0,
#  'ingredients_from_palm_oil_n': 0,
#  'ingredients_from_palm_oil_tags': [],
#  'ingredients_hierarchy': ['en:carbonated-water',
#   'en:water',
#   'en:sugar',
#   'en:added-sugar',
#   'en:disaccharide',
#   'en:colour',
#   'en:acidity-requlator',
#   'en:caffeine',
#   'en:other-flavourings',
#   'en:150d',
#   'en:338'],
#  'ingredients_ids_debug': [],
#  'ingredients_lc': 'en',
#  'ingredients_n': 8,
#  'ingredients_n_tags': ['8', '1-10'],
#  'ingredients_non_nutritive_sweeteners_n': 0,
#  'ingredients_original_tags': ['en:carbonated-water',
#   'en:sugar',
#   'en:colour',
#   'en:acidity-requlator',
#   'en:caffeine',
#   'en:other-flavourings',
#   'en:150d',
#   'en:338'],
#  'ingredients_percent_analysis': 1,
#  'ingredients_sweeteners_n': 0,
#  'ingredients_tags': ['en:carbonated-water',
#   'en:water',
#   'en:sugar',
#   'en:added-sugar',
#   'en:disaccharide',
#   'en:colour',
#   'en:acidity-requlator',
#   'en:caffeine',
#   'en:other-flavourings',
#   'en:150d',
#   'en:338'],
#  'ingredients_text': 'Carbonated Water, Sugar, Colour (150d), Acidity Requlator (338), Caffeine and other Flavourings.',
#  'ingredients_text_debug': '',
#  'ingredients_text_en': 'Carbonated Water, Sugar, Colour (150d), Acidity Requlator (338), Caffeine and other Flavourings.',
#  'ingredients_text_with_allergens': 'Carbonated Water, Sugar, Colour (150d), Acidity Requlator (338), Caffeine and other Flavourings.',
#  'ingredients_text_with_allergens_en': 'Carbonated Water, Sugar, Colour (150d), Acidity Requlator (338), Caffeine and other Flavourings.',
#  'ingredients_that_may_be_from_palm_oil_n': 0,
#  'ingredients_that_may_be_from_palm_oil_tags': [],
#  'ingredients_with_specified_percent_n': 0,
#  'ingredients_with_specified_percent_sum': 0,
#  'ingredients_with_unspecified_percent_n': 6,
#  'ingredients_with_unspecified_percent_sum': 100,
#  'ingredients_without_ciqual_codes': ['en:150d',
#   'en:338',
#   'en:acidity-requlator',
#   'en:caffeine',
#   'en:colour',
#   'en:other-flavourings'],
#  'ingredients_without_ciqual_codes_n': 6,
#  'ingredients_without_ecobalyse_ids': ['en:150d',
#   'en:338',
#   'en:acidity-requlator',
#   'en:caffeine',
#   'en:colour',
#   'en:other-flavourings'],
#  'ingredients_without_ecobalyse_ids_n': 6,
#  'interface_version_created': '20120622',
#  'interface_version_modified': '20150316.jqm2',
#  'known_ingredients_n': 7,
#  'labels': '',
#  'labels_hierarchy': [],
#  'labels_lc': 'en',
#  'labels_old': '',
#  'labels_tags': [],
#  'lang': 'en',
#  'languages': {'en:english': 4},
#  'languages_codes': {'en': 4},
#  'languages_hierarchy': ['en:english'],
#  'languages_tags': ['en:english', 'en:1'],
#  'last_edit_dates_tags': ['2023-01-13', '2023-01', '2023'],
#  'last_editor': 'smoothie-app',
#  'last_image_dates_tags': ['2021-12-02', '2021-12', '2021'],
#  'last_image_t': 1638425974,
#  'last_modified_by': 'smoothie-app',
#  'last_modified_t': 1673634070,
#  'last_updated_t': 1738768058,
#  'lc': 'en',
#  'link': '',
#  'main_countries_tags': [],
#  'manufacturing_places': 'hong kong',
#  'manufacturing_places_tags': ['hong-kong'],
#  'max_imgid': '2',
#  'minerals_prev_tags': [],
#  'minerals_tags': [],
#  'misc_tags': ['en:environmental-score-extended-data-not-computed',
#   'en:environmental-score-not-applicable',
#   'en:environmental-score-not-computed',
#   'en:nutriscore-2021-e-2023-e',
#   'en:nutriscore-2021-same-as-2023',
#   'en:nutriscore-computed',
#   'en:nutrition-all-nutriscore-values-known',
#   'en:nutrition-fruits-vegetables-legumes-estimate-from-ingredients',
#   'en:nutrition-fruits-vegetables-nuts-estimate-from-ingredients',
#   'en:packagings-not-complete',
#   'en:packagings-not-empty',
#   'en:packagings-not-empty-but-not-complete',
#   'en:packagings-number-of-components-1'],
#  'no_nutrition_data': '',
#  'nova_group': 4,
#  'nova_group_debug': '',
#  'nova_groups': '4',
#  'nova_groups_markers': {'3': [['categories', 'en:sodas'],
#    ['ingredients', 'en:sugar']],
#   '4': [['additives', 'en:e150d'], ['ingredients', 'en:colour']]},
#  'nova_groups_tags': ['en:4-ultra-processed-food-and-drink-products'],
#  'nucleotides_prev_tags': [],
#  'nucleotides_tags': [],
#  'nutrient_levels': {'fat': 'low',
#   'salt': 'low',
#   'saturated-fat': 'low',
#   'sugars': 'high'},
#  'nutrient_levels_tags': ['en:fat-in-low-quantity',
#   'en:saturated-fat-in-low-quantity',
#   'en:sugars-in-high-quantity',
#   'en:salt-in-low-quantity'],
#  'nutriments': {'carbohydrates': 10.6,
#   'carbohydrates_100g': 10.6,
#   'carbohydrates_unit': 'g',
#   'carbohydrates_value': 10.6,
#   'energy': 176,
#   'energy-kcal': 42,
#   'energy-kcal_100g': 42,
#   'energy-kcal_unit': 'kcal',
#   'energy-kcal_value': 42,
#   'energy-kcal_value_computed': 42.4,
#   'energy_100g': 176,
#   'energy_unit': 'kcal',
#   'energy_value': 42,
#   'fat': 0,
#   'fat_100g': 0,
#   'fat_unit': 'g',
#   'fat_value': 0,
#   'fiber': 0,
#   'fiber_100g': 0,
#   'fiber_unit': 'g',
#   'fiber_value': 0,
#   'fruits-vegetables-legumes-estimate-from-ingredients_100g': 0,
#   'fruits-vegetables-legumes-estimate-from-ingredients_serving': 0,
#   'fruits-vegetables-nuts-estimate-from-ingredients_100g': 0,
#   'fruits-vegetables-nuts-estimate-from-ingredients_serving': 0,
#   'nova-group': 4,
#   'nova-group_100g': 4,
#   'nova-group_serving': 4,
#   'nutrition-score-fr': 12,
#   'nutrition-score-fr_100g': 12,
#   'proteins': 0,
#   'proteins_100g': 0,
#   'proteins_unit': 'g',
#   'proteins_value': 0,
#   'salt': 0.01,
#   'salt_100g': 0.01,
#   'salt_unit': 'mg',
#   'salt_value': 10,
#   'saturated-fat': 0,
#   'saturated-fat_100g': 0,
#   'saturated-fat_unit': 'g',
#   'saturated-fat_value': 0,
#   'sodium': 0.004,
#   'sodium_100g': 0.004,
#   'sodium_unit': 'mg',
#   'sodium_value': 4,
#   'sugars': 10.6,
#   'sugars_100g': 10.6,
#   'sugars_unit': 'g',
#   'sugars_value': 10.6},
#  'nutriscore': {'2021': {'category_available': 1,
#    'data': {'energy': 176,
#     'energy_points': 6,
#     'energy_value': 176,
#     'fiber': 0,
#     'fiber_points': 0,
#     'fiber_value': 0,
#     'fruits_vegetables_nuts_colza_walnut_olive_oils': 0,
#     'fruits_vegetables_nuts_colza_walnut_olive_oils_points': 0,
#     'fruits_vegetables_nuts_colza_walnut_olive_oils_value': 0,
#     'is_beverage': 1,
#     'is_cheese': 0,
#     'is_fat': 0,
#     'is_water': 0,
#     'negative_points': 14,
#     'positive_points': 0,
#     'proteins': 0,
#     'proteins_points': 0,
#     'proteins_value': 0,
#     'saturated_fat': 0,
#     'saturated_fat_points': 0,
#     'saturated_fat_value': 0,
#     'sodium': 4,
#     'sodium_points': 0,
#     'sodium_value': 4,
#     'sugars': 10.6,
#     'sugars_points': 8,
#     'sugars_value': 10.6},
#    'grade': 'e',
#    'nutrients_available': 1,
#    'nutriscore_applicable': 1,
#    'nutriscore_computed': 1,
#    'score': 14},
#   '2023': {'category_available': 1,
#    'data': {'components': {'negative': [{'id': 'energy',
#        'points': 3,
#        'points_max': 10,
#        'unit': 'kJ',
#        'value': 176},
#       {'id': 'sugars',
#        'points': 9,
#        'points_max': 10,
#        'unit': 'g',
#        'value': 10.6},
#       {'id': 'saturated_fat',
#        'points': 0,
#        'points_max': 10,
#        'unit': 'g',
#        'value': 0},
#       {'id': 'salt',
#        'points': 0,
#        'points_max': 20,
#        'unit': 'g',
#        'value': 0.01},
#       {'id': 'non_nutritive_sweeteners',
#        'points': 0,
#        'points_max': 4,
#        'unit': 'number',
#        'value': 0}],
#      'positive': [{'id': 'proteins',
#        'points': 0,
#        'points_max': 7,
#        'unit': 'g',
#        'value': 0},
#       {'id': 'fiber', 'points': 0, 'points_max': 5, 'unit': 'g', 'value': 0},
#       {'id': 'fruits_vegetables_legumes',
#        'points': 0,
#        'points_max': 6,
#        'unit': '%',
#        'value': 0}]},
#     'count_proteins': 1,
#     'count_proteins_reason': 'beverage',
#     'is_beverage': 1,
#     'is_cheese': 0,
#     'is_fat_oil_nuts_seeds': 0,
#     'is_red_meat_product': 0,
#     'is_water': 0,
#     'negative_points': 12,
#     'negative_points_max': 54,
#     'positive_nutrients': ['proteins', 'fiber', 'fruits_vegetables_legumes'],
#     'positive_points': 0,
#     'positive_points_max': 18},
#    'grade': 'e',
#    'nutrients_available': 1,
#    'nutriscore_applicable': 1,
#    'nutriscore_computed': 1,
#    'score': 12}},
#  'nutriscore_2021_tags': ['e'],
#  'nutriscore_2023_tags': ['e'],
#  'nutriscore_data': {'components': {'negative': [{'id': 'energy',
#      'points': 3,
#      'points_max': 10,
#      'unit': 'kJ',
#      'value': 176},
#     {'id': 'sugars',
#      'points': 9,
#      'points_max': 10,
#      'unit': 'g',
#      'value': 10.6},
#     {'id': 'saturated_fat',
#      'points': 0,
#      'points_max': 10,
#      'unit': 'g',
#      'value': 0},
#     {'id': 'salt', 'points': 0, 'points_max': 20, 'unit': 'g', 'value': 0.01},
#     {'id': 'non_nutritive_sweeteners',
#      'points': 0,
#      'points_max': 4,
#      'unit': 'number',
#      'value': 0}],
#    'positive': [{'id': 'proteins',
#      'points': 0,
#      'points_max': 7,
#      'unit': 'g',
#      'value': 0},
#     {'id': 'fiber', 'points': 0, 'points_max': 5, 'unit': 'g', 'value': 0},
#     {'id': 'fruits_vegetables_legumes',
#      'points': 0,
#      'points_max': 6,
#      'unit': '%',
#      'value': 0}]},
#   'count_proteins': 1,
#   'count_proteins_reason': 'beverage',
#   'grade': 'e',
#   'is_beverage': 1,
#   'is_cheese': 0,
#   'is_fat_oil_nuts_seeds': 0,
#   'is_red_meat_product': 0,
#   'is_water': 0,
#   'negative_points': 12,
#   'negative_points_max': 54,
#   'positive_nutrients': ['proteins', 'fiber', 'fruits_vegetables_legumes'],
#   'positive_points': 0,
#   'positive_points_max': 18,
#   'score': 12},
#  'nutriscore_grade': 'e',
#  'nutriscore_score': 12,
#  'nutriscore_score_opposite': -12,
#  'nutriscore_tags': ['e'],
#  'nutriscore_version': '2023',
#  'nutrition_data': 'null',
#  'nutrition_data_per': '100g',
#  'nutrition_data_prepared_per': '100g',
#  'nutrition_grade_fr': 'e',
#  'nutrition_grades': 'e',
#  'nutrition_grades_tags': ['e'],
#  'nutrition_score_beverage': 1,
#  'nutrition_score_debug': '',
#  'nutrition_score_warning_fruits_vegetables_legumes_estimate_from_ingredients': 1,
#  'nutrition_score_warning_fruits_vegetables_legumes_estimate_from_ingredients_value': 0,
#  'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients': 1,
#  'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients_value': 0,
#  'origins': '',
#  'origins_hierarchy': [],
#  'origins_lc': 'en',
#  'origins_old': '',
#  'origins_tags': [],
#  'other_nutritional_substances_tags': [],
#  'packaging': 'Aluminium can',
#  'packaging_hierarchy': ['en:Aluminium can'],
#  'packaging_lc': 'en',
#  'packaging_materials_tags': ['en:aluminium'],
#  'packaging_old': 'Aluminium can',
#  'packaging_old_before_taxonomization': 'aluminium can',
#  'packaging_recycling_tags': [],
#  'packaging_shapes_tags': ['en:can'],
#  'packaging_tags': ['en:aluminium-can'],
#  'packagings': [{'material': 'en:aluminium', 'shape': 'en:can'}],
#  'packagings_materials': {'all': {}, 'en:metal': {}},
#  'packagings_n': 1,
#  'photographers_tags': ['momowong', 'kinosan'],
#  'pnns_groups_1': 'Beverages',
#  'pnns_groups_1_tags': ['beverages', 'known'],
#  'pnns_groups_2': 'Sweetened beverages',
#  'pnns_groups_2_tags': ['sweetened-beverages', 'known'],
#  'popularity_key': 23900000010,
#  'popularity_tags': ['bottom-25-percent-scans-2019',
#   'top-80-percent-scans-2019',
#   'top-85-percent-scans-2019',
#   'top-90-percent-scans-2019',
#   'top-100-id-scans-2019',
#   'top-500-id-scans-2019',
#   'top-1000-id-scans-2019',
#   'top-5000-id-scans-2019',
#   'top-10000-id-scans-2019',
#   'top-50000-id-scans-2019',
#   'top-100000-id-scans-2019',
#   'top-country-id-scans-2019',
#   'top-500-cz-scans-2019',
#   'top-1000-cz-scans-2019',
#   'top-5000-cz-scans-2019',
#   'top-10000-cz-scans-2019',
#   'top-50000-cz-scans-2019',
#   'top-100000-cz-scans-2019',
#   'top-50000-be-scans-2019',
#   'top-100000-be-scans-2019',
#   'top-100000-scans-2020',
#   'at-least-5-scans-2020',
#   'top-75-percent-scans-2020',
#   'top-80-percent-scans-2020',
#   'top-85-percent-scans-2020',
#   'top-90-percent-scans-2020',
#   'top-500-in-scans-2020',
#   'top-1000-in-scans-2020',
#   'top-5000-in-scans-2020',
#   'top-10000-in-scans-2020',
#   'top-50000-in-scans-2020',
#   'top-100000-in-scans-2020',
#   'top-country-in-scans-2020',
#   'top-1000-hk-scans-2020',
#   'top-5000-hk-scans-2020',
#   'top-10000-hk-scans-2020',
#   'top-50000-hk-scans-2020',
#   'top-100000-hk-scans-2020',
#   'top-10000-nl-scans-2020',
#   'top-50000-nl-scans-2020',
#   'top-100000-nl-scans-2020',
#   'top-500-vn-scans-2020',
#   'top-1000-vn-scans-2020',
#   'top-5000-vn-scans-2020',
#   'top-10000-vn-scans-2020',
#   'top-50000-vn-scans-2020',
#   'top-100000-vn-scans-2020',
#   'top-50000-scans-2021',
#   'top-100000-scans-2021',
#   'at-least-5-scans-2021',
#   'at-least-10-scans-2021',
#   'top-75-percent-scans-2021',
#   'top-80-percent-scans-2021',
#   'top-85-percent-scans-2021',
#   'top-90-percent-scans-2021',
#   'top-5000-at-scans-2021',
#   'top-10000-at-scans-2021',
#   'top-50000-at-scans-2021',
#   'top-100000-at-scans-2021',
#   'top-country-at-scans-2021',
#   'top-500-hk-scans-2021',
#   'top-1000-hk-scans-2021',
#   'top-5000-hk-scans-2021',
#   'top-10000-hk-scans-2021',
#   'top-50000-hk-scans-2021',
#   'top-100000-hk-scans-2021',
#   'top-100-pk-scans-2021',
#   'top-500-pk-scans-2021',
#   'top-1000-pk-scans-2021',
#   'top-5000-pk-scans-2021',
#   'top-10000-pk-scans-2021',
#   'top-50000-pk-scans-2021',
#   'top-100000-pk-scans-2021',
#   'top-1000-dk-scans-2021',
#   'top-5000-dk-scans-2021',
#   'top-10000-dk-scans-2021',
#   'top-50000-dk-scans-2021',
#   'top-100000-dk-scans-2021',
#   'top-50000-it-scans-2021',
#   'top-100000-it-scans-2021',
#   'top-500-mk-scans-2021',
#   'top-1000-mk-scans-2021',
#   'top-5000-mk-scans-2021',
#   'top-10000-mk-scans-2021',
#   'top-50000-mk-scans-2021',
#   'top-100000-mk-scans-2021',
#   'top-50000-us-scans-2021',
#   'top-100000-us-scans-2021',
#   'top-5000-au-scans-2021',
#   'top-10000-au-scans-2021',
#   'top-50000-au-scans-2021',
#   'top-100000-au-scans-2021',
#   'top-100-mn-scans-2021',
#   'top-500-mn-scans-2021',
#   'top-1000-mn-scans-2021',
#   'top-5000-mn-scans-2021',
#   'top-10000-mn-scans-2021',
#   'top-50000-mn-scans-2021',
#   'top-100000-mn-scans-2021',
#   'top-10000-ca-scans-2021',
#   'top-50000-ca-scans-2021',
#   'top-100000-ca-scans-2021',
#   'top-500-cg-scans-2021',
#   'top-1000-cg-scans-2021',
#   'top-5000-cg-scans-2021',
#   'top-10000-cg-scans-2021',
#   'top-50000-cg-scans-2021',
#   'top-100000-cg-scans-2021',
#   'top-500-vn-scans-2021',
#   'top-1000-vn-scans-2021',
#   'top-5000-vn-scans-2021',
#   'top-10000-vn-scans-2021',
#   'top-50000-vn-scans-2021',
#   'top-100000-vn-scans-2021',
#   'top-10000-be-scans-2021',
#   'top-50000-be-scans-2021',
#   'top-100000-be-scans-2021',
#   'top-1000-eg-scans-2021',
#   'top-5000-eg-scans-2021',
#   'top-10000-eg-scans-2021',
#   'top-50000-eg-scans-2021',
#   'top-100000-eg-scans-2021',
#   'top-50000-scans-2022',
#   'top-100000-scans-2022',
#   'at-least-5-scans-2022',
#   'at-least-10-scans-2022',
#   'top-75-percent-scans-2022',
#   'top-80-percent-scans-2022',
#   'top-85-percent-scans-2022',
#   'top-90-percent-scans-2022',
#   'top-50000-fr-scans-2022',
#   'top-100000-fr-scans-2022',
#   'top-country-fr-scans-2022',
#   'top-1000-nl-scans-2022',
#   'top-5000-nl-scans-2022',
#   'top-10000-nl-scans-2022',
#   'top-50000-nl-scans-2022',
#   'top-100000-nl-scans-2022',
#   'top-1000-th-scans-2022',
#   'top-5000-th-scans-2022',
#   'top-10000-th-scans-2022',
#   'top-50000-th-scans-2022',
#   'top-100000-th-scans-2022',
#   'top-1000-ca-scans-2022',
#   'top-5000-ca-scans-2022',
#   'top-10000-ca-scans-2022',
#   'top-50000-ca-scans-2022',
#   'top-100000-ca-scans-2022',
#   'top-5000-ua-scans-2022',
#   'top-10000-ua-scans-2022',
#   'top-50000-ua-scans-2022',
#   'top-100000-ua-scans-2022',
#   'top-50-cn-scans-2022',
#   'top-100-cn-scans-2022',
#   'top-500-cn-scans-2022',
#   'top-1000-cn-scans-2022',
#   'top-5000-cn-scans-2022',
#   'top-10000-cn-scans-2022',
#   'top-50000-cn-scans-2022',
#   'top-100000-cn-scans-2022',
#   'top-500-hk-scans-2022',
#   'top-1000-hk-scans-2022',
#   'top-5000-hk-scans-2022',
#   'top-10000-hk-scans-2022',
#   'top-50000-hk-scans-2022',
#   'top-100000-hk-scans-2022',
#   'top-50000-scans-2023',
#   'top-100000-scans-2023',
#   'at-least-5-scans-2023',
#   'at-least-10-scans-2023',
#   'top-75-percent-scans-2023',
#   'top-80-percent-scans-2023',
#   'top-85-percent-scans-2023',
#   'top-90-percent-scans-2023',
#   'top-5000-nl-scans-2023',
#   'top-10000-nl-scans-2023',
#   'top-50000-nl-scans-2023',
#   'top-100000-nl-scans-2023',
#   'top-country-nl-scans-2023',
#   'top-50000-es-scans-2023',
#   'top-100000-es-scans-2023',
#   'top-500-uy-scans-2023',
#   'top-1000-uy-scans-2023',
#   'top-5000-uy-scans-2023',
#   'top-10000-uy-scans-2023',
#   'top-50000-uy-scans-2023',
#   'top-100000-uy-scans-2023',
#   'top-50-mn-scans-2023',
#   'top-100-mn-scans-2023',
#   'top-500-mn-scans-2023',
#   'top-1000-mn-scans-2023',
#   'top-5000-mn-scans-2023',
#   'top-10000-mn-scans-2023',
#   'top-50000-mn-scans-2023',
#   'top-100000-mn-scans-2023',
#   'top-1000-md-scans-2023',
#   'top-5000-md-scans-2023',
#   'top-10000-md-scans-2023',
#   'top-50000-md-scans-2023',
#   'top-100000-md-scans-2023',
#   'top-10000-ru-scans-2023',
#   'top-50000-ru-scans-2023',
#   'top-100000-ru-scans-2023',
#   'top-50000-pt-scans-2023',
#   'top-100000-pt-scans-2023',
#   'top-50000-us-scans-2023',
#   'top-100000-us-scans-2023',
#   'top-50-lk-scans-2023',
#   'top-100-lk-scans-2023',
#   'top-500-lk-scans-2023',
#   'top-1000-lk-scans-2023',
#   'top-5000-lk-scans-2023',
#   'top-10000-lk-scans-2023',
#   'top-50000-lk-scans-2023',
#   'top-100000-lk-scans-2023',
#   'top-100000-scans-2024',
#   'at-least-5-scans-2024',
#   'at-least-10-scans-2024',
#   'top-75-percent-scans-2024',
#   'top-80-percent-scans-2024',
#   'top-85-percent-scans-2024',
#   'top-90-percent-scans-2024',
#   'top-500-hk-scans-2024',
#   'top-1000-hk-scans-2024',
#   'top-5000-hk-scans-2024',
#   'top-10000-hk-scans-2024',
#   'top-50000-hk-scans-2024',
#   'top-100000-hk-scans-2024',
#   'top-country-hk-scans-2024',
#   'top-500-by-scans-2024',
#   'top-1000-by-scans-2024',
#   'top-5000-by-scans-2024',
#   'top-10000-by-scans-2024',
#   'top-50000-by-scans-2024',
#   'top-100000-by-scans-2024',
#   'top-500-mt-scans-2024',
#   'top-1000-mt-scans-2024',
#   'top-5000-mt-scans-2024',
#   'top-10000-mt-scans-2024',
#   'top-50000-mt-scans-2024',
#   'top-100000-mt-scans-2024',
#   'top-500-jp-scans-2024',
#   'top-1000-jp-scans-2024',
#   'top-5000-jp-scans-2024',
#   'top-10000-jp-scans-2024',
#   'top-50000-jp-scans-2024',
#   'top-100000-jp-scans-2024',
#   'top-500-az-scans-2024',
#   'top-1000-az-scans-2024',
#   'top-5000-az-scans-2024',
#   'top-10000-az-scans-2024',
#   'top-50000-az-scans-2024',
#   'top-100000-az-scans-2024',
#   'top-10000-in-scans-2024',
#   'top-50000-in-scans-2024',
#   'top-100000-in-scans-2024',
#   'top-10000-ca-scans-2024',
#   'top-50000-ca-scans-2024',
#   'top-100000-ca-scans-2024',
#   'top-5000-ru-scans-2024',
#   'top-10000-ru-scans-2024',
#   'top-50000-ru-scans-2024',
#   'top-100000-ru-scans-2024',
#   'top-500-sg-scans-2024',
#   'top-1000-sg-scans-2024',
#   'top-5000-sg-scans-2024',
#   'top-10000-sg-scans-2024',
#   'top-50000-sg-scans-2024',
#   'top-100000-sg-scans-2024'],
#  'product_name': 'Coca-Cola',
#  'product_name_en': 'Coca-Cola',
#  'product_quantity': '330',
#  'product_quantity_unit': 'ml',
#  'product_type': 'food',
#  'purchase_places': 'Hong Kong',
#  'purchase_places_tags': ['hong-kong'],
#  'quantity': '330ml',
#  'removed_countries_tags': [],
#  'rev': 12,
#  'scans_n': 12,
#  'selected_images': {'front': {'display': {'en': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/front_en.4.400.jpg'},
#    'small': {'en': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/front_en.4.200.jpg'},
#    'thumb': {'en': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/front_en.4.100.jpg'}},
#   'ingredients': {'display': {'en': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/ingredients_en.9.400.jpg'},
#    'small': {'en': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/ingredients_en.9.200.jpg'},
#    'thumb': {'en': 'https://images.openfoodfacts.org/images/products/489/000/810/0309/ingredients_en.9.100.jpg'}}},
#  'sortkey': 1451465149,
#  'states': 'en:to-be-completed, en:nutrition-facts-completed, en:ingredients-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:origins-to-be-completed, en:categories-completed, en:brands-completed, en:packaging-completed, en:quantity-completed, en:product-name-completed, en:photos-to-be-validated, en:packaging-photo-to-be-selected, en:nutrition-photo-to-be-selected, en:ingredients-photo-selected, en:front-photo-selected, en:photos-uploaded',
#  'states_hierarchy': ['en:to-be-completed',
#   'en:nutrition-facts-completed',
#   'en:ingredients-completed',
#   'en:expiration-date-to-be-completed',
#   'en:packaging-code-to-be-completed',
#   'en:characteristics-to-be-completed',
#   'en:origins-to-be-completed',
#   'en:categories-completed',
#   'en:brands-completed',
#   'en:packaging-completed',
#   'en:quantity-completed',
#   'en:product-name-completed',
#   'en:photos-to-be-validated',
#   'en:packaging-photo-to-be-selected',
#   'en:nutrition-photo-to-be-selected',
#   'en:ingredients-photo-selected',
#   'en:front-photo-selected',
#   'en:photos-uploaded'],
#  'states_tags': ['en:to-be-completed',
#   'en:nutrition-facts-completed',
#   'en:ingredients-completed',
#   'en:expiration-date-to-be-completed',
#   'en:packaging-code-to-be-completed',
#   'en:characteristics-to-be-completed',
#   'en:origins-to-be-completed',
#   'en:categories-completed',
#   'en:brands-completed',
#   'en:packaging-completed',
#   'en:quantity-completed',
#   'en:product-name-completed',
#   'en:photos-to-be-validated',
#   'en:packaging-photo-to-be-selected',
#   'en:nutrition-photo-to-be-selected',
#   'en:ingredients-photo-selected',
#   'en:front-photo-selected',
#   'en:photos-uploaded'],
#  'stores': 'Supermarket',
#  'stores_tags': ['supermarket'],
#  'traces': '',
#  'traces_from_ingredients': '',
#  'traces_from_user': '(en) ',
#  'traces_hierarchy': [],
#  'traces_tags': [],
#  'unique_scans_n': 10,
#  'unknown_ingredients_n': 4,
#  'unknown_nutrients_tags': [],
#  'update_key': 'sort',
#  'vitamins_prev_tags': [],
#  'vitamins_tags': []}
